# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14665, done.
# remote: Total 14665 (delta 0), reused 0 (delta 0), pack-reused 14665
# Receiving objects: 100% (14665/14665), 13.25 MiB | 23.32 MiB/s, done.
# Resolving deltas: 100% (9977/9977), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 2000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov3_training.cfg

# %%
# !echo -e 'koyun' > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data

# %%
# !cp cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3/yolov3_testing.cfg
# !cp data/obj.names /content/gdrive/MyDrive/yolov3/classes.txt

# %%
# !rm -rf /content/darknet/data/obj

# %%
# !mkdir data/obj
# !unzip /content/gdrive/MyDrive/yolov3/images.zip -d data/obj
# Out:
# Archive:  /content/gdrive/MyDrive/yolov3/images.zip
#   inflating: data/obj/sheep1_png.rf.5346fea080c62f57f6db6d71fc2d8ce5.txt
#   inflating: data/obj/sheep3_png.rf.2aaf9c748da1ca72a07fb75f74cc6237.jpg
#   inflating: data/obj/sheep3_png.rf.2aaf9c748da1ca72a07fb75f74cc6237.txt
#   inflating: data/obj/sheep4_png.rf.5d0c0cc63b381e2c3c6d0df038b0cba7.jpg
#   inflating: data/obj/sheep4_png.rf.5d0c0cc63b381e2c3c6d0df038b0cba7.txt
#   inflating: data/obj/sheep5_png.rf.fe3f1680f3681c3f9373253f25a6b7f5.jpg
#   inflating: data/obj/sheep5_png.rf.fe3f1680f3681c3f9373253f25a6b7f5.txt
#   inflating: data/obj/sheep6_png.rf.154dc298921de069a2108281f1a52fd9.jpg
#   inflating: data/obj/sheep6_png.rf.154dc298921de069a2108281f1a52fd9.txt
#   inflating: data/obj/sheep10_png.rf.a801d560a07e0329bb7bce8f06a55d19.jpg
#   inflating: data/obj/sheep10_png.rf.a801d560a07e0329bb7bce8f06a55d19.txt
#   inflating: data/obj/sheep12_png.rf.9114998ce255450414a1d5f72f4ca199.jpg
# ...

# %%
import glob
images_list = glob.glob("data/obj/*.jpg")
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-01-08 21:35:55--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  5.36MB/s    in 28s
#
# 2021-01-08 21:36:24 (5.59 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg /content/darknet/darknet53.conv.74 -dont_show
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.297898), count: 1, class_loss = 0.270342, iou_loss = 0.768154, total_loss = 1.038496
#  total_bbox = 69674, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.722452), count: 6, class_loss = 0.376996, iou_loss = 0.414322, total_loss = 0.791317
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000033, iou_loss = 0.000000, total_loss = 0.000033
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 69680, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.701257), count: 4, class_loss = 0.134793, iou_loss = 0.219415, total_loss = 0.354208
# ...
